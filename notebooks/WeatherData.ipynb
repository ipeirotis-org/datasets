# %% [markdown]
# https://www.ncdc.noaa.gov/cdo-web/datasets
#
# FTP server at https://www1.ncdc.noaa.gov/pub/data/ghcn/daily/
#
# Yearly files: https://www1.ncdc.noaa.gov/pub/data/ghcn/daily/by_year/
# Each CSV file is ~1Gb uncompressed.

# %%
import pandas as pd

# %%
df = pd.read_csv("2017.csv.gz")

# %%
len(df)
# Out:
# 34583642

# %%
#From: https://www1.ncdc.noaa.gov/pub/data/ghcn/daily/by_year/ghcn-daily-by_year-format.rtf
df.columns = ['ID', 'DATE', 'ELEMENT', 'VALUE', 'M_FLAG', 'Q_FLAG', 'S_FLAG', 'OBS_TIME']

# %% [markdown]
# Documentation at https://www1.ncdc.noaa.gov/pub/data/ghcn/daily/readme.txt
#
# Relevant files from https://www1.ncdc.noaa.gov/pub/data/ghcn/daily/
# * ghcnd-countries.txt
# * ghcnd-states.txt
# * ghcnd-inventory.txt
# * ghcnd-stations.txt

# %%
df
# Out:
#                    ID      DATE ELEMENT  VALUE M_FLAG Q_FLAG S_FLAG  OBS_TIME
# 0         US1MISW0005  20170101    SNOW      0    NaN    NaN      N       NaN
# 1         US1MISW0005  20170101    SNWD      0    NaN    NaN      N       NaN
# 2         CA1MB000296  20170101    PRCP      0    NaN    NaN      N       NaN
# 3         ASN00015643  20170101    TMAX    274    NaN    NaN      a       NaN
# 4         ASN00015643  20170101    TMIN    218    NaN    NaN      a       NaN
# 5         ASN00015643  20170101    PRCP      2    NaN    NaN      a       NaN
# 6         US1LAEB0041  20170101    PRCP    950    NaN    NaN      N       NaN
# 7         US1MAMD0069  20170101    PRCP     56    NaN    NaN      N       NaN
# 8         ASN00085296  20170101    TMAX    217    NaN    NaN      a       NaN
# 9         ASN00085296  20170101    TMIN    127    NaN    NaN      a       NaN
# 10        ASN00085296  20170101    PRCP      0    NaN    NaN      a       NaN
# ...
