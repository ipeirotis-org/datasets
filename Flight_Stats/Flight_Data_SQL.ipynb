# %%
# Data from
# https://www.transtats.bts.gov/DL_SelectFields.asp?Table_ID=236

# Airport timezones
# https://gist.github.com/andrewcole/8760689

# %%
import pandas as pd 
import numpy as np
import datetime
from pytz import timezone

# %%
tz = pd.read_csv("https://gist.githubusercontent.com/mj1856/6d219c48697c550c2476/raw/ce1bc0666772fd9bcd839318b713836b78bba9be/timezones.csv")

# %%
tz = tz.set_index('iata_code').drop('windows_tz', axis='columns')

# %%
#Get a airport code - return the Time Zone
def get_time_zone(x):
    return tz.loc[x].iana_tz

get_time_zone('JFK')
# Out:
# 'America/New_York'

# %%
df = pd.read_table("JAN2018.csv", sep=",", dtype = 'object')

# %%
df.head()
# Out:
#       FL_DATE OP_UNIQUE_CARRIER OP_CARRIER_FL_NUM ORIGIN DEST CRS_DEP_TIME  \
# 0  2018-01-01                UA              2429    EWR  DEN         1517
# 1  2018-01-01                UA              2427    LAS  SFO         1115
# 2  2018-01-01                UA              2426    SNA  DEN         1335
# 3  2018-01-01                UA              2425    RSW  ORD         1546
# 4  2018-01-01                UA              2424    ORD  ALB         0630
#
#   DEP_TIME DEP_DELAY CRS_ARR_TIME ARR_TIME ARR_DELAY CANCELLED  \
# 0     1512     -5.00         1745     1722    -23.00      0.00
# 1     1107     -8.00         1254     1230    -24.00      0.00
# 2     1330     -5.00         1649     1636    -13.00      0.00
# 3     1552      6.00         1756     1754     -2.00      0.00
# 4     0650     20.00         0922     0936     14.00      0.00
#
#   CANCELLATION_CODE DIVERTED CRS_ELAPSED_TIME ACTUAL_ELAPSED_TIME AIR_TIME  \
# 0               NaN     0.00           268.00              250.00   225.00
# 1               NaN     0.00            99.00               83.00    65.00
# 2               NaN     0.00           134.00              126.00   106.00
# 3               NaN     0.00           190.00              182.00   157.00
# 4               NaN     0.00           112.00              106.00    83.00
#
#   DISTANCE Unnamed: 18
# 0  1605.00         NaN
# 1   414.00         NaN
# 2   846.00         NaN
# 3  1120.00         NaN
# 4   723.00         NaN

# %%
df.dtypes
# Out:
# FL_DATE                object
# OP_UNIQUE_CARRIER      object
# OP_CARRIER_FL_NUM      object
# ORIGIN                 object
# DEST                   object
# CRS_DEP_TIME           object
# DEP_TIME               object
# DEP_DELAY              object
# CRS_ARR_TIME           object
# ARR_TIME               object
# ARR_DELAY              object
# CANCELLED              object
# CANCELLATION_CODE      object
# DIVERTED               object
# CRS_ELAPSED_TIME       object
# ACTUAL_ELAPSED_TIME    object
# AIR_TIME               object
# DISTANCE               object
# Unnamed: 18            object
# dtype: object

# %%
def to_time(x):
    if type(x)==type('str') and len(x)==4:
        if x == '2400':
            return '00:00'
        else:
            return x[:2]+':'+x[2:]
    else:
        return x

# %%
#Convert to Time 
df['CRS_DEP_TIME'] = df['CRS_DEP_TIME'].astype(str).apply(to_time)
df['CRS_ARR_TIME'] = df['CRS_ARR_TIME'].astype(str).apply(to_time)

df['DEP_TIME']     = df['DEP_TIME'].astype(str).apply(to_time)
df['ARR_TIME']     = df['ARR_TIME'].astype(str).apply(to_time)

# %%
df['CRS_DEP_TIME'] = df['FL_DATE'] + " " + df['CRS_DEP_TIME']
df['CRS_ARR_TIME'] = df['FL_DATE'] + " " + df['CRS_ARR_TIME']
df['DEP_TIME'] = df['FL_DATE'] + " " + df['DEP_TIME']
df['ARR_TIME'] = df['FL_DATE'] + " " + df['ARR_TIME']

# %%
df['CRS_DEP_TIME'] = pd.to_datetime(df.CRS_DEP_TIME, format='%Y-%m-%d %H:%M')
df['CRS_ARR_TIME'] = pd.to_datetime(df.CRS_ARR_TIME, format='%Y-%m-%d %H:%M')
df['DEP_TIME'] = pd.to_datetime(df.DEP_TIME, format='%Y-%m-%d %H:%M', errors= 'coerce')
df['ARR_TIME'] = pd.to_datetime(df.ARR_TIME, format='%Y-%m-%d %H:%M', errors= 'coerce')

# %%
def convert(row):
    tz = timezone(get_time_zone(row['ORIGIN']))
    return tz.localize(row['CRS_DEP_TIME'])
    
df['CRS_DEP_TIME'] = df.apply(convert, axis='columns')

# %%
def convert(row):
    if pd.notna(row['DEP_TIME']):
        tz = timezone(get_time_zone(row['ORIGIN']))
        return tz.localize(row['DEP_TIME'])
    else:
        return None
    
df['DEP_TIME'] = df.apply(convert, axis='columns')

# %%
def convert_dest_time(row):
    if pd.notna(row['ARR_TIME']):
        origin = row['DEST']
        origin_tz = timezone(get_time_zone(origin))
        dep_time = row['ARR_TIME']
        return origin_tz.localize(dep_time)
    else:
        return None
    
df['ARR_TIME'] = df.apply(convert_dest_time, axis='columns')

# %%
def convert_dest_time(row):
    origin = row['DEST']
    origin_tz = timezone(get_time_zone(origin))
    dep_time = row['CRS_ARR_TIME']
    return origin_tz.localize(dep_time)
    
df['CRS_ARR_TIME'] = df.apply(convert_dest_time, axis='columns')

# %%
df.head()
# Out:
#       FL_DATE OP_UNIQUE_CARRIER OP_CARRIER_FL_NUM ORIGIN DEST  \
# 0  2018-01-01                UA              2429    EWR  DEN
# 1  2018-01-01                UA              2427    LAS  SFO
# 2  2018-01-01                UA              2426    SNA  DEN
# 3  2018-01-01                UA              2425    RSW  ORD
# 4  2018-01-01                UA              2424    ORD  ALB
#
#                 CRS_DEP_TIME                   DEP_TIME DEP_DELAY  \
# 0  2018-01-01 15:17:00-05:00  2018-01-01 15:12:00-05:00     -5.00
# 1  2018-01-01 11:15:00-08:00  2018-01-01 11:07:00-08:00     -8.00
# 2  2018-01-01 13:35:00-08:00  2018-01-01 13:30:00-08:00     -5.00
# 3  2018-01-01 15:46:00-05:00  2018-01-01 15:52:00-05:00      6.00
# 4  2018-01-01 06:30:00-06:00  2018-01-01 06:50:00-06:00     20.00
#
#                 CRS_ARR_TIME                   ARR_TIME ARR_DELAY CANCELLED  \
# 0  2018-01-01 17:45:00-07:00  2018-01-01 17:22:00-07:00    -23.00      0.00
# 1  2018-01-01 12:54:00-08:00  2018-01-01 12:30:00-08:00    -24.00      0.00
# 2  2018-01-01 16:49:00-07:00  2018-01-01 16:36:00-07:00    -13.00      0.00
# 3  2018-01-01 17:56:00-06:00  2018-01-01 17:54:00-06:00     -2.00      0.00
# 4  2018-01-01 09:22:00-05:00  2018-01-01 09:36:00-05:00     14.00      0.00
#
#   CANCELLATION_CODE DIVERTED CRS_ELAPSED_TIME ACTUAL_ELAPSED_TIME AIR_TIME  \
# 0               NaN     0.00           268.00              250.00   225.00
# 1               NaN     0.00            99.00               83.00    65.00
# 2               NaN     0.00           134.00              126.00   106.00
# 3               NaN     0.00           190.00              182.00   157.00
# 4               NaN     0.00           112.00              106.00    83.00
#
#   DISTANCE Unnamed: 18
# 0  1605.00         NaN
# 1   414.00         NaN
# 2   846.00         NaN
# 3  1120.00         NaN
# 4   723.00         NaN

# %%
df['DEP_TIME'].loc[0] > df['ARR_TIME'].loc[0]
# Out:
# False

# %%
df = df.drop(['FL_DATE', 'Unnamed: 18'], axis='columns')

# %%
df = df.rename(
    {
       "OP_UNIQUE_CARRIER": "AIRLINE",
        "OP_CARRIER_FL_NUM": "FLIGHT_NUM",
        'CRS_DEP_TIME': 'SCHED_DEP',
        'DEP_TIME': 'ACTUAL_DEP',
        'CRS_ARR_TIME': 'SCHED_ARR',
        'ARR_TIME': 'ACTUAL_ARR',
        
    },
    axis = 'columns'
)

# %%
df.dtypes
# Out:
# AIRLINE                object
# FLIGHT_NUM             object
# ORIGIN                 object
# DEST                   object
# SCHED_DEP              object
# ACTUAL_DEP             object
# DEP_DELAY              object
# SCHED_ARR              object
# ACTUAL_ARR             object
# ARR_DELAY              object
# CANCELLED              object
# CANCELLATION_CODE      object
# DIVERTED               object
# CRS_ELAPSED_TIME       object
# ACTUAL_ELAPSED_TIME    object
# AIR_TIME               object
# DISTANCE               object
# dtype: object

# %%
df.head(10)
# Out:
#   AIRLINE FLIGHT_NUM ORIGIN DEST                  SCHED_DEP  \
# 0      UA       2429    EWR  DEN  2018-01-01 15:17:00-05:00
# 1      UA       2427    LAS  SFO  2018-01-01 11:15:00-08:00
# 2      UA       2426    SNA  DEN  2018-01-01 13:35:00-08:00
# 3      UA       2425    RSW  ORD  2018-01-01 15:46:00-05:00
# 4      UA       2424    ORD  ALB  2018-01-01 06:30:00-06:00
# 5      UA       2422    ORD  OMA  2018-01-01 22:41:00-06:00
# 6      UA       2421    IAH  LAS  2018-01-01 07:50:00-06:00
# 7      UA       2420    DEN  CID  2018-01-01 13:24:00-07:00
# 8      UA       2419    SMF  EWR  2018-01-01 22:24:00-08:00
# 9      UA       2418    RIC  DEN  2018-01-01 16:01:00-05:00
#
#                   ACTUAL_DEP DEP_DELAY                  SCHED_ARR  \
# 0  2018-01-01 15:12:00-05:00     -5.00  2018-01-01 17:45:00-07:00
# 1  2018-01-01 11:07:00-08:00     -8.00  2018-01-01 12:54:00-08:00
# 2  2018-01-01 13:30:00-08:00     -5.00  2018-01-01 16:49:00-07:00
# 3  2018-01-01 15:52:00-05:00      6.00  2018-01-01 17:56:00-06:00
# 4  2018-01-01 06:50:00-06:00     20.00  2018-01-01 09:22:00-05:00
# 5  2018-01-01 22:44:00-06:00      3.00  2018-01-01 00:14:00-06:00
# 6  2018-01-01 07:47:00-06:00     -3.00  2018-01-01 09:16:00-08:00
# 7  2018-01-01 13:18:00-07:00     -6.00  2018-01-01 16:19:00-06:00
# 8  2018-01-01 22:37:00-08:00     13.00  2018-01-01 06:38:00-05:00
# 9  2018-01-01 15:59:00-05:00     -2.00  2018-01-01 18:13:00-07:00
#
#                   ACTUAL_ARR ARR_DELAY CANCELLED CANCELLATION_CODE DIVERTED  \
# 0  2018-01-01 17:22:00-07:00    -23.00      0.00               NaN     0.00
# 1  2018-01-01 12:30:00-08:00    -24.00      0.00               NaN     0.00
# 2  2018-01-01 16:36:00-07:00    -13.00      0.00               NaN     0.00
# 3  2018-01-01 17:54:00-06:00     -2.00      0.00               NaN     0.00
# 4  2018-01-01 09:36:00-05:00     14.00      0.00               NaN     0.00
# 5  2018-01-01 00:03:00-06:00    -11.00      0.00               NaN     0.00
# 6  2018-01-01 09:00:00-08:00    -16.00      0.00               NaN     0.00
# 7  2018-01-01 16:00:00-06:00    -19.00      0.00               NaN     0.00
# 8  2018-01-01 06:36:00-05:00     -2.00      0.00               NaN     0.00
# 9  2018-01-01 17:56:00-07:00    -17.00      0.00               NaN     0.00
#
#   CRS_ELAPSED_TIME ACTUAL_ELAPSED_TIME AIR_TIME DISTANCE
# 0           268.00              250.00   225.00  1605.00
# 1            99.00               83.00    65.00   414.00
# 2           134.00              126.00   106.00   846.00
# 3           190.00              182.00   157.00  1120.00
# 4           112.00              106.00    83.00   723.00
# 5            93.00               79.00    62.00   416.00
# 6           206.00              193.00   173.00  1222.00
# 7           115.00              102.00    85.00   692.00
# 8           314.00              299.00   280.00  2500.00
# 9           252.00              237.00   217.00  1482.00

# %%
def fix_arr(row):
    x = row['SCHED_ARR']
    if row['SCHED_DEP'] > row['SCHED_ARR']:
        return row['SCHED_ARR'] + datetime.timedelta(days=1)
    else:
        return row['SCHED_ARR']
    
df['SCHED_ARR'] = df.apply(fix_arr, axis='columns')

# %%
df[ df]
# Out:
#   AIRLINE FLIGHT_NUM ORIGIN DEST                  SCHED_DEP  \
# 0      UA       2429    EWR  DEN  2018-01-01 15:17:00-05:00
# 1      UA       2427    LAS  SFO  2018-01-01 11:15:00-08:00
# 2      UA       2426    SNA  DEN  2018-01-01 13:35:00-08:00
# 3      UA       2425    RSW  ORD  2018-01-01 15:46:00-05:00
# 4      UA       2424    ORD  ALB  2018-01-01 06:30:00-06:00
# 5      UA       2422    ORD  OMA  2018-01-01 22:41:00-06:00
# 6      UA       2421    IAH  LAS  2018-01-01 07:50:00-06:00
# 7      UA       2420    DEN  CID  2018-01-01 13:24:00-07:00
# 8      UA       2419    SMF  EWR  2018-01-01 22:24:00-08:00
# 9      UA       2418    RIC  DEN  2018-01-01 16:01:00-05:00
#
#                   ACTUAL_DEP DEP_DELAY                  SCHED_ARR  \
# 0  2018-01-01 15:12:00-05:00     -5.00  2018-01-01 17:45:00-07:00
# 1  2018-01-01 11:07:00-08:00     -8.00  2018-01-01 12:54:00-08:00
# 2  2018-01-01 13:30:00-08:00     -5.00  2018-01-01 16:49:00-07:00
# 3  2018-01-01 15:52:00-05:00      6.00  2018-01-01 17:56:00-06:00
# 4  2018-01-01 06:50:00-06:00     20.00  2018-01-01 09:22:00-05:00
# 5  2018-01-01 22:44:00-06:00      3.00  2018-01-02 00:14:00-06:00
# 6  2018-01-01 07:47:00-06:00     -3.00  2018-01-01 09:16:00-08:00
# 7  2018-01-01 13:18:00-07:00     -6.00  2018-01-01 16:19:00-06:00
# 8  2018-01-01 22:37:00-08:00     13.00  2018-01-02 06:38:00-05:00
# 9  2018-01-01 15:59:00-05:00     -2.00  2018-01-01 18:13:00-07:00
#
#                   ACTUAL_ARR ARR_DELAY CANCELLED CANCELLATION_CODE DIVERTED  \
# 0  2018-01-01 17:22:00-07:00    -23.00      0.00               NaN     0.00
# 1  2018-01-01 12:30:00-08:00    -24.00      0.00               NaN     0.00
# 2  2018-01-01 16:36:00-07:00    -13.00      0.00               NaN     0.00
# 3  2018-01-01 17:54:00-06:00     -2.00      0.00               NaN     0.00
# 4  2018-01-01 09:36:00-05:00     14.00      0.00               NaN     0.00
# 5  2018-01-01 00:03:00-06:00    -11.00      0.00               NaN     0.00
# 6  2018-01-01 09:00:00-08:00    -16.00      0.00               NaN     0.00
# 7  2018-01-01 16:00:00-06:00    -19.00      0.00               NaN     0.00
# 8  2018-01-01 06:36:00-05:00     -2.00      0.00               NaN     0.00
# 9  2018-01-01 17:56:00-07:00    -17.00      0.00               NaN     0.00
#
#   CRS_ELAPSED_TIME ACTUAL_ELAPSED_TIME AIR_TIME DISTANCE
# 0           268.00              250.00   225.00  1605.00
# 1            99.00               83.00    65.00   414.00
# 2           134.00              126.00   106.00   846.00
# 3           190.00              182.00   157.00  1120.00
# 4           112.00              106.00    83.00   723.00
# 5            93.00               79.00    62.00   416.00
# 6           206.00              193.00   173.00  1222.00
# 7           115.00              102.00    85.00   692.00
# 8           314.00              299.00   280.00  2500.00
# 9           252.00              237.00   217.00  1482.00

# %%
# Rename Columns 
df.rename({'FL_DATE': 'departureDate', 
            'OP_UNIQUE_CARRIER': 'airline',
            'OP_CARRIER_FL_NUM': 'flightNumber',
            'ORIGIN': 'departureAirport',
            'DEST': 'arrivalAirport',
            'CRS_DEP_TIME': 'scheduledDeparture',
            'DEP_TIME': 'actualDeparture',
            'CRS_ARR_TIME': 'scheduledArrival',
            'ARR_TIME': 'actualArrival',
            'ARR_DELAY': 'arrivalDelay',
            'CANCELLED': 'isCancelled',
            'DIVERTED': 'isDiverted',
            'CRS_ELAPSED_TIME': 'scheduledDuration',
            'ACTUAL_ELAPSED_TIME': 'actualDuration',
            'WEATHER_DELAY': 'weatherDelay',
            'NAS_DELAY': 'airTrafficDelay',
            'SECURITY_DELAY': 'securityDelay',
            'LATE_AIRCRAFT_DELAY': 'lateAircraftDelay',
            'CARRIER_DELAY': 'carrierDelay',
            'DEP_DELAY': 'departureDelay'
          }, axis='columns', inplace = True)

# %%
df.head()

# %%
# Connect to SQL 
from sqlalchemy import create_engine

conn_string = 'mysql://{user}:{password}@{host}/flights?charset=utf8mb4'.format(
    host = '35.237.67.210', 
    user = 'root',
    password = 'b8EzunlmLy2zNq87')

engine = create_engine(conn_string)
con = engine.connect()

# %%
#Send Data to SQL 
df.to_sql(name = "flight_data_new", con = engine, index = False, if_exists = 'append', chunksize=1000)
print("Done")
